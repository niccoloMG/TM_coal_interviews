# %% [markdown]
# show the topic categories, topic names, numbers and keywords

# %%
import pandas as pd
import time #to have today's date
timestr = time.strftime("%Y%m%d")

# %%
df_topics_categories_num = pd.read_csv\
('.//results//master_dfs//category_numname_topics_numname_orinew_keywords_lambda_'+timestr+'_V01.csv',
    sep=';', decimal=',', index_col=0)

# %%
df_topics_categories_num
# Out:
#     Category_num               Category_label  Topic_num  \
# 0              1           Actors & interests          1
# 1              1           Actors & interests          2
# 2              1           Actors & interests          3
# 3              1           Actors & interests          4
# 4              2        Electric power system          5
# 5              2        Electric power system          6
# 6              2        Electric power system          7
# 7              2        Electric power system          8
# 8              2        Electric power system          9
# 9              3  Energy governance & markets         10
# 10             3  Energy governance & markets         11
# 11             3  Energy governance & markets         12
# 12             3  Energy governance & markets         13
# 13             3  Energy governance & markets         14
# 14             3  Energy governance & markets         15
# ...

# %%
df_topics_categories_num.groupby(['Category_label'])[['topic_score_%']].sum()
# Out:
#                              topic_score_%
# Category_label
# Actors & interests                    13.8
# Electric power system                 28.8
# Energy governance & markets           37.6
# Policies                              19.7
